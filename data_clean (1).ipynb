# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("laptopPrice.csv")

# %%
dataset
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
#del df['column_name']
#del dataset['ram_type']
del dataset['os']
del dataset['os_bit']
del dataset['graphic_card_gb']
del dataset['weight']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            823 non-null    object
#  1   processor_brand  823 non-null    object
#  2   processor_name   823 non-null    object
#  3   processor_gnrtn  823 non-null    object
#  4   ram_gb           823 non-null    object
#  5   ram_type         823 non-null    object
#  6   ssd              823 non-null    object
#  7   hdd              823 non-null    object
#  8   Touchscreen      823 non-null    object
#  9   Price            823 non-null    int64
#  10  rating           823 non-null    int64
# dtypes: int64(2), object(9)
# memory usage: 70.9+ KB

# %%
dataset.drop(['Number of Reviews', 'Number of Ratings','msoffice','warranty'], axis = 1, inplace = True)

# %%
dataset.isnull().sum()
# Out:
# brand              0
# processor_brand    0
# processor_name     0
# processor_gnrtn    0
# ram_gb             0
# ram_type           0
# ssd                0
# hdd                0
# Touchscreen        0
# Price              0
# rating             0
# dtype: int64

# %%
dataset['rating'] = dataset['rating'].str.replace(' stars', '')
dataset['rating'] = pd.to_numeric(dataset['rating'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1 star"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 dataset['rating'] = dataset['rating'].str.replace(' stars', '')
# ----> 2 dataset['rating'] = pd.to_numeric(dataset['rating'])
#
# File D:\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
# ...

# %%
print(dataset.to_string())
# Out:
#       brand processor_brand processor_name processor_gnrtn  ram_gb   ssd   hdd Touchscreen   Price  rating
# 0      ASUS           Intel        Core i3              10       4     0  1024          No   34649       2
# 1    Lenovo           Intel        Core i3              10       4     0  1024          No   38999       3
# 2    Lenovo           Intel        Core i3              10       4     0  1024          No   39999       3
# 3      ASUS           Intel        Core i5              10       8   512     0          No   69990       3
# 4      ASUS           Intel   Celeron Dual   Not Available       4     0   512          No   26990       3
# 5      ASUS           Intel   Celeron Dual   Not Available       4     0   512          No   22990       3
# 6      ASUS           Intel   Celeron Dual   Not Available       4     0   512          No   21990       3
# 7      ASUS           Intel        Core i5              10       8     0  1024          No   58799       3
# ...

# %%
dataset['rating'] = dataset['rating'].str.replace(' star', '')
dataset['rating'] = pd.to_numeric(dataset['rating'])

# %%
dataset['hdd'] = dataset['hdd'].str.replace(' GB', '')
dataset['hdd'] = pd.to_numeric(dataset['hdd'])

# %%
dataset['ssd'] = dataset['ssd'].str.replace(' GB', '')
dataset['ssd'] = pd.to_numeric(dataset['ssd'])

# %%
del dataset['ram_type']

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            823 non-null    object
#  1   processor_brand  823 non-null    object
#  2   processor_name   823 non-null    object
#  3   processor_gnrtn  823 non-null    object
#  4   ram_gb           823 non-null    object
#  5   ssd              823 non-null    int64
#  6   hdd              823 non-null    int64
#  7   Touchscreen      823 non-null    object
#  8   Price            823 non-null    int64
#  9   rating           823 non-null    int64
# dtypes: int64(4), object(6)
# memory usage: 64.4+ KB

# %%
dataset['ram_gb'] = dataset['ram_gb'].str.replace(' GB', '')
dataset['ram_gb'] = pd.to_numeric(dataset['ram_gb'])

# %%
dataset['processor_gnrtn'] = dataset['processor_gnrtn'].str.replace('th', '')
dataset['processor_gnrtn'] = pd.to_numeric(dataset['processor_gnrtn'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Not Available"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 dataset['processor_gnrtn'] = dataset['processor_gnrtn'].str.replace('th', '')
# ----> 2 dataset['processor_gnrtn'] = pd.to_numeric(dataset['processor_gnrtn'])
#
# File D:\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
# ...

# %%
dataset.processor_gnrtn.replace('Not Available',np.nan)
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4      NaN
#       ...
# 818    NaN
# 819    NaN
# 820    NaN
# 821    NaN
# 822     10
# Name: processor_gnrtn, Length: 823, dtype: object

# %%
dataset.processor_gnrtn = pd.to_numeric(dataset.processor_gnrtn,errors='coerce')

# %%
dataset.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn    225
# ram_gb               0
# ssd                  0
# hdd                  0
# Touchscreen          0
# Price                0
# rating               0
# dtype: int64

# %%
dataset = dataset.dropna(subset=['processor_gnrtn'])
print(dataset.to_string())
# Out:
#       brand processor_brand processor_name  processor_gnrtn  ram_gb   ssd   hdd Touchscreen   Price  rating
# 0      ASUS           Intel        Core i3             10.0       4     0  1024          No   34649       2
# 1    Lenovo           Intel        Core i3             10.0       4     0  1024          No   38999       3
# 2    Lenovo           Intel        Core i3             10.0       4     0  1024          No   39999       3
# 3      ASUS           Intel        Core i5             10.0       8   512     0          No   69990       3
# 7      ASUS           Intel        Core i5             10.0       8     0  1024          No   58799       3
# 8    Lenovo           Intel        Core i5             10.0       4     0  1024          No   49999       3
# 9      acer             AMD        Ryzen 5             10.0       4     0   512          No   59990       4
# 10     acer             AMD        Ryzen 5             10.0       4     0   512          No   93700       4
# ...

# %%
dataset['processor_gnrtn'] = dataset['processor_gnrtn'].astype(int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12232\2139704933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['processor_gnrtn'] = dataset['processor_gnrtn'].astype(int)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 598 entries, 0 to 822
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            598 non-null    object
#  1   processor_brand  598 non-null    object
#  2   processor_name   598 non-null    object
#  3   processor_gnrtn  598 non-null    int32
#  4   ram_gb           598 non-null    int64
#  5   ssd              598 non-null    int64
#  6   hdd              598 non-null    int64
#  7   Touchscreen      598 non-null    object
#  8   Price            598 non-null    int64
#  9   rating           598 non-null    int64
# dtypes: int32(1), int64(5), object(4)
# memory usage: 49.1+ KB

# %%
print(dataset.to_string())
# Out:
#       brand processor_brand processor_name  processor_gnrtn  ram_gb   ssd   hdd Touchscreen   Price  rating
# 0      ASUS           Intel        Core i3               10       4     0  1024          No   34649       2
# 1    Lenovo           Intel        Core i3               10       4     0  1024          No   38999       3
# 2    Lenovo           Intel        Core i3               10       4     0  1024          No   39999       3
# 3      ASUS           Intel        Core i5               10       8   512     0          No   69990       3
# 7      ASUS           Intel        Core i5               10       8     0  1024          No   58799       3
# 8    Lenovo           Intel        Core i5               10       4     0  1024          No   49999       3
# 9      acer             AMD        Ryzen 5               10       4     0   512          No   59990       4
# 10     acer             AMD        Ryzen 5               10       4     0   512          No   93700       4
# ...

# %%
dataset['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Ryzen 5', 'Core i7', 'Core i9', 'M1'],
#       dtype=object)

# %%
print(dataset.duplicated().sum())
# Out:
# 0

# %%
dataset.drop_duplicates(inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12232\2870039874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (559, 10)

# %%
print(dataset.to_string())
# Out:
#       brand processor_brand processor_name  processor_gnrtn  ram_gb   ssd   hdd  Touchscreen   Price  rating
# 0      ASUS           Intel        Core i3               10       4     0  1024            0   34649       2
# 1    Lenovo           Intel        Core i3               10       4     0  1024            0   38999       3
# 2    Lenovo           Intel        Core i3               10       4     0  1024            0   39999       3
# 3      ASUS           Intel        Core i5               10       8   512     0            0   69990       3
# 7      ASUS           Intel        Core i5               10       8     0  1024            0   58799       3
# 8    Lenovo           Intel        Core i5               10       4     0  1024            0   49999       3
# 9      acer             AMD        Ryzen 5               10       4     0   512            0   59990       4
# 10     acer             AMD        Ryzen 5               10       4     0   512            0   93700       4
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 559 entries, 0 to 822
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            559 non-null    object
#  1   processor_brand  559 non-null    object
#  2   processor_name   559 non-null    object
#  3   processor_gnrtn  559 non-null    int32
#  4   ram_gb           559 non-null    int64
#  5   ssd              559 non-null    int64
#  6   hdd              559 non-null    int64
#  7   Touchscreen      559 non-null    object
#  8   Price            559 non-null    int64
#  9   rating           559 non-null    int64
# dtypes: int32(1), int64(5), object(4)
# memory usage: 45.9+ KB

# %%
dataset['Touchscreen'] = dataset['Touchscreen'].apply(lambda x:1 if 'Yes' in x else 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12232\2246581304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Touchscreen'] = dataset['Touchscreen'].apply(lambda x:1 if 'Yes' in x else 0)

# %%
#reset index of dataframe
dataset=dataset.reset_index(drop=True)

# %%
print(dataset.to_string())
# Out:
#       brand processor_brand processor_name  processor_gnrtn  ram_gb   ssd   hdd  Touchscreen   Price  rating
# 0      ASUS           Intel        Core i3               10       4     0  1024            0   34649       2
# 1    Lenovo           Intel        Core i3               10       4     0  1024            0   38999       3
# 2    Lenovo           Intel        Core i3               10       4     0  1024            0   39999       3
# 3      ASUS           Intel        Core i5               10       8   512     0            0   69990       3
# 4      ASUS           Intel        Core i5               10       8     0  1024            0   58799       3
# 5    Lenovo           Intel        Core i5               10       4     0  1024            0   49999       3
# 6      acer             AMD        Ryzen 5               10       4     0   512            0   59990       4
# 7      acer             AMD        Ryzen 5               10       4     0   512            0   93700       4
# ...

# %%
dataset.to_csv("clean_data.csv")
